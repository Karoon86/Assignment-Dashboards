# %% [markdown]
# Prompt 4:
#
# Does the GitHub link view the dashboard you provided include the Demographics dashboard tab, which uses the data asset m5_survey_data_demographics.csv and captures the following metrics as visualizations?
#
#
# Use Filters for this tab feature to filter out entries of other types except Man and Woman from the data point Gender.

# %%
df = df[df['Gender'].apply(lambda x: x in ['Man', 'Woman'])]
df.head(5)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7fce6010-8229-4183-9f12-9d2faa631cc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fce6010-8229-4183-9f12-9d2faa631cc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("m5_survey_data_demographics.csv")
df.head(5)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
df.columns.tolist()

# %% [markdown]
# In the first rectangle (Panel 1):

# %% [markdown]
# Capture Top 10 Respondent classified by Gender.

# %%
df['Gender'].value_counts().head(10)
# Out:
# Gender
# Man      10480
# Woman      731
# Name: count, dtype: int64

# %% [markdown]
# Visualize as a Pie chart.

# %% [markdown]
# Utilize Segments, Size fields of Pie chart.

# %%
# It's likely that the 'Gender' column has mixed data types.
# Convert the column to a consistent type, likely string:

df['Gender'] = df['Gender'].astype(str)

# %%
# Now try the plotting code again:
df['Gender'].value_counts().head(10).plot(kind='pie')
plt.show()

# %% [markdown]
# In the second rectangle (Panel 2):

# %% [markdown]
# Capture Respondent Count for Countries.

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# United States     3058
# India              890
# United Kingdom     808
# Germany            693
# Canada             426
# France             333
# Brazil             321
# Australia          280
# Spain              250
# Netherlands        248
# Name: count, dtype: int64

# %% [markdown]
# Utilize Regions-Locations, Regions-Location color fields of Map chart.

# %%
# !pip install geopandas
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
# Assuming 'Country' column contains country names
country_counts = df['Country'].value_counts()

# Load a world map shapefile
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# <ipython-input-39-989d447dc337>:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
# Merge country counts with the world map
world = world.merge(country_counts.rename('Count'), left_on='name', right_index=True, how='left')

# %%
#  Create the map
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
world.plot(column='Count', cmap='viridis', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
ax.set_title('Respondent Count by Country')
plt.show()

# %% [markdown]
# In the third rectangle (Panel 3):

# %% [markdown]
# Capture Respondent Count by Age.

# %%
df['Age'].value_counts().head(10)
# Out:
# Age
# 28.0    774
# 25.0    724
# 26.0    706
# 27.0    706
# 29.0    683
# 24.0    666
# 30.0    639
# 23.0    570
# 31.0    521
# 32.0    485
# Name: count, dtype: int64

# %% [markdown]
# Visualize as a Line chart.

# %%
df['Age'].value_counts().head(10).plot(kind='line')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# Utilize x-axis, y-axis fields of Line chart.

# %%
df["Age"].value_counts().head(10).plot(kind="line", figsize=(10, 6), color="blue")
plt.title("Top 10 Age Number")
plt.ylabel('Number of Respondents')
plt.xlabel('Age')
plt.show()

# %%
df["Age"].value_counts().head(10).plot(kind="line", figsize=(10, 6), color="blue", marker='o')
plt.title("Top 10 Age Number")
plt.ylabel('Number of Respondents')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# In the fourth rectangle (Panel 4):

# %% [markdown]
# Capture Respondent Count by Gender, classified by Formal Education Level.

# %%
df['EdLevel'].value_counts().head(10)
# Out:
# EdLevel
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              5753
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           2675
# Some college/university study without earning a degree                                1330
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     506
# Associate degree                                                                       377
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              256
# Professional degree (JD, MD, etc.)                                                     152
# I never completed any formal education                                                  27
# Primary/elementary school                                                               26
# Name: count, dtype: int64

# %%
df.groupby(['Gender', 'EdLevel']).size().head(10)
# Out:
# Gender  EdLevel
# Man     Associate degree                                                                       357
#         Bachelor’s degree (BA, BS, B.Eng., etc.)                                              5341
#         I never completed any formal education                                                  26
#         Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           2484
#         Other doctoral degree (Ph.D, Ed.D., etc.)                                              241
#         Primary/elementary school                                                               26
#         Professional degree (JD, MD, etc.)                                                     144
#         Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     482
#         Some college/university study without earning a degree                                1280
# ...

# %%
df.groupby(['Gender', 'EdLevel']).size().head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Gender,EdLevel'>

# %% [markdown]
# Visualize as a Stacked bar chart.

# %%
df.groupby(['Gender', 'EdLevel']).size().head(10).plot.barh(stacked=True)
# Out:
# <Axes: ylabel='Gender,EdLevel'>
